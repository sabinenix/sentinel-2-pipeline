# %% [markdown]
# # Sentinel-2 Access with STAC and AWS Open Data Registry

# %% [markdown]
# ### AWS Open Data Registry
# The AWS Open Data Registry hosts many different geospatial datasets. Sentinel-2, for example, is stored in a requester-pays S3 bucket which is made available for anyone to access and download or copy to their own S3 bucket.
#
# ### STAC Specification
#
# STAC stands for spatiotemporal asset catalogs. STAC is a specification for indexing geospatial datasets and aims to make data more accessible by standardizing the way that is searched for and discovered.
#
# Anyone interested in accessing data can use STAC to easily find relevant data and reduce the need to write custom code for each dataset integration.
#
# > "The goal is for all providers of spatiotemporal assets (Imagery, SAR, Point Clouds, Data Cubes, Full Motion Video, etc) to expose their data as SpatioTemporal Asset Catalogs (STAC), so that new code doesn't need to be written whenever a new data set or API is released." ([stacspec.org](https://stacspec.org/en/))

# %% [markdown]
# ### Useful Links:
#
# - [Sentinel-2 Cloud-Optimized GeoTIFFs on AWS Registry of Open Data](https://registry.opendata.aws/sentinel-2-l2a-cogs/)
# - [STAC Specification](https://stacspec.org/en)
# - [AWS Open Data Registry GitHub Repo](https://github.com/awslabs/open-data-registry)
# - [Carpentries Tutorial on Accessing Satellite Imagery with STAC](https://carpentries-incubator.github.io/geospatial-python/05-access-data.html)

# %% [markdown]
# This Jupyter Notebook walks through the process of searching for Sentinel-2 data matching a user's data request using STAC and then copying the relevant Sentinel-2 scenes from the source bucket on AWS Open Data Registry to the destination bucket in the Cecil science AWS account.

# %% [markdown]
# ###

# %% [markdown]
# ### Import required packages
# We use the package `pystac_client` to read the url for the Earth Search STAC catalog API. The Earth Search catalog is a central search catalog for the open geospatial datasets on AWS, including Sentinel-2.
#
# We use `json` to construct metadata files for each Sentinel-2 scene.

# %%
from pystac_client import Client
import json

# %% [markdown]
# ### Search for data matching our parameters.
# Next, we set up the conditions we will search for. For simplicity, this example is using a bounding box representing the Kakadu National Park AOI. We also specify a start and end time, and the name of the collection we are searching for (in this case, "sentinel-2-l2a").
#
# We then search the Earth Search STAC catalog using these parameters and examine the items that are returned.

# %%
# Kakadu National Park as bounding box
bbox = [132.52934211276073, -12.730063400794094, 132.54027735328083, -12.721072673008706]
start_time = "2023-09-01"
end_time = "2023-09-20"
collection_name = "sentinel-2-l2a"


# STAC Catalog URL to search for scenes.
catalog = Client.open("https://earth-search.aws.element84.com/v1/")

# Search for items instersecting our bbox and within desired date range.
query = catalog.search(
    collections=[collection_name],
    datetime=f"{start_time}/{end_time}",
    bbox=bbox
)

# TODO: subset the scenes before copying them over

# Print the number of items found from executing the query.
items = query.item_collection()
print(f"Found {len(items)} Sentinel-2 scenes")

# Convert the query result to a json format (if desired to get full list of matching scenes and all metzdata).
stac_json = query.item_collection_as_dict()

# Print information about each item in the collection.
for item in items:
    print(item.id)
    print(item.datetime)
    print(item.properties)
    print(item.assets.keys())
# Out:
# Found 3 Sentinel-2 scenes
# S2A_52LHM_20230918_0_L2A
# 2023-09-18 01:30:48.372000+00:00
# {'created': '2023-09-18T07:42:46.728Z', 'platform': 'sentinel-2a', 'constellation': 'sentinel-2', 'instruments': ['msi'], 'eo:cloud_cover': 5.355347, 'mgrs:utm_zone': 52, 'mgrs:latitude_band': 'L', 'mgrs:grid_square': 'HM', 'grid:code': 'MGRS-52LHM', 'view:sun_azimuth': 60.28929408308, 'view:sun_elevation': 62.529655401736804, 's2:degraded_msi_data_percentage': 0.0017, 's2:nodata_pixel_percentage': 1.603352, 's2:saturated_defective_pixel_percentage': 0, 's2:dark_features_percentage': 0.000455, 's2:cloud_shadow_percentage': 0.192144, 's2:vegetation_percentage': 17.785923, 's2:not_vegetated_percentage': 36.154309, 's2:water_percentage': 39.901057, 's2:unclassified_percentage': 0.610766, 's2:medium_proba_clouds_percentage': 0.641282, 's2:high_proba_clouds_percentage': 0.558218, 's2:thin_cirrus_percentage': 4.155846, 's2:snow_ice_percentage': 0, 's2:product_type': 'S2MSI2A', 's2:processing_baseline': '05.09', 's2:product_uri': 'S2A_MSIL2A_20230918T012721_N0509_R131_T52LHM_20230918T041455.SAFE', 's2:generation_time': '2023-09-18T04:14:55.000000Z', 's2:datatake_id': 'GS2A_20230918T012721_043028_N05.09', 's2:datatake_type': 'INS-NOBS', 's2:datastrip_id': 'S2A_OPER_MSI_L2A_DS_2APS_20230918T041455_S20230918T013035_N05.09', 's2:granule_id': 'S2A_OPER_MSI_L2A_TL_2APS_20230918T041455_A043028_T52LHM_N05.09', 's2:reflectance_conversion_factor': 0.988585295379002, 'datetime': '2023-09-18T01:30:48.372000Z', 's2:sequence': '0', 'earthsearch:s3_path': 's3://sentinel-cogs/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A', 'earthsearch:payload_id': 'roda-sentinel2/workflow-sentinel2-to-stac/94358f3d43934702c1c478c265b40289', 'earthsearch:boa_offset_applied': True, 'processing:software': {'sentinel2-to-stac': '0.1.1'}, 'updated': '2023-09-18T07:42:46.728Z', 'proj:code': 'EPSG:32752'}
# dict_keys(['aot', 'blue', 'coastal', 'granule_metadata', 'green', 'nir', 'nir08', 'nir09', 'red', 'rededge1', 'rededge2', 'rededge3', 'scl', 'swir16', 'swir22', 'thumbnail', 'tileinfo_metadata', 'visual', 'wvp', 'aot-jp2', 'blue-jp2', 'coastal-jp2', 'green-jp2', 'nir-jp2', 'nir08-jp2', 'nir09-jp2', 'red-jp2', 'rededge1-jp2', 'rededge2-jp2', 'rededge3-jp2', 'scl-jp2', 'swir16-jp2', 'swir22-jp2', 'visual-jp2', 'wvp-jp2'])
# S2A_53LKG_20230918_0_L2A
# 2023-09-18 01:30:47.337000+00:00
# {'created': '2023-09-18T07:44:13.763Z', 'platform': 'sentinel-2a', 'constellation': 'sentinel-2', 'instruments': ['msi'], 'eo:cloud_cover': 13.971867, 'mgrs:utm_zone': 53, 'mgrs:latitude_band': 'L', 'mgrs:grid_square': 'KG', 'grid:code': 'MGRS-53LKG', 'view:sun_azimuth': 59.7150226214647, 'view:sun_elevation': 62.931111210594, 's2:degraded_msi_data_percentage': 0.0004, 's2:nodata_pixel_percentage': 7.061911, 's2:saturated_defective_pixel_percentage': 0, 's2:dark_features_percentage': 0.031194, 's2:cloud_shadow_percentage': 2.310547, 's2:vegetation_percentage': 20.33904, 's2:not_vegetated_percentage': 46.083573, 's2:water_percentage': 16.350846, 's2:unclassified_percentage': 0.912935, 's2:medium_proba_clouds_percentage': 3.249957, 's2:high_proba_clouds_percentage': 3.52399, 's2:thin_cirrus_percentage': 7.19792, 's2:snow_ice_percentage': 0, 's2:product_type': 'S2MSI2A', 's2:processing_baseline': '05.09', 's2:product_uri': 'S2A_MSIL2A_20230918T012721_N0509_R131_T53LKG_20230918T041455.SAFE', 's2:generation_time': '2023-09-18T04:14:55.000000Z', 's2:datatake_id': 'GS2A_20230918T012721_043028_N05.09', 's2:datatake_type': 'INS-NOBS', 's2:datastrip_id': 'S2A_OPER_MSI_L2A_DS_2APS_20230918T041455_S20230918T013035_N05.09', 's2:granule_id': 'S2A_OPER_MSI_L2A_TL_2APS_20230918T041455_A043028_T53LKG_N05.09', 's2:reflectance_conversion_factor': 0.988585295379002, 'datetime': '2023-09-18T01:30:47.337000Z', 's2:sequence': '0', 'earthsearch:s3_path': 's3://sentinel-cogs/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A', 'earthsearch:payload_id': 'roda-sentinel2/workflow-sentinel2-to-stac/d0654592c7089317b69ea41889b1b764', 'earthsearch:boa_offset_applied': True, 'processing:software': {'sentinel2-to-stac': '0.1.1'}, 'updated': '2023-09-18T07:44:13.763Z', 'proj:code': 'EPSG:32753'}
# dict_keys(['aot', 'blue', 'coastal', 'granule_metadata', 'green', 'nir', 'nir08', 'nir09', 'red', 'rededge1', 'rededge2', 'rededge3', 'scl', 'swir16', 'swir22', 'thumbnail', 'tileinfo_metadata', 'visual', 'wvp', 'aot-jp2', 'blue-jp2', 'coastal-jp2', 'green-jp2', 'nir-jp2', 'nir08-jp2', 'nir09-jp2', 'red-jp2', 'rededge1-jp2', 'rededge2-jp2', 'rededge3-jp2', 'scl-jp2', 'swir16-jp2', 'swir22-jp2', 'visual-jp2', 'wvp-jp2'])
# S2A_53LKF_20230908_0_L2A
# 2023-09-08 01:31:03.482000+00:00
# {'created': '2023-09-08T11:50:16.401Z', 'platform': 'sentinel-2a', 'constellation': 'sentinel-2', 'instruments': ['msi'], 'eo:cloud_cover': 0.016473, 'mgrs:utm_zone': 53, 'mgrs:latitude_band': 'L', 'mgrs:grid_square': 'KF', 'grid:code': 'MGRS-53LKF', 'view:sun_azimuth': 52.8724058935537, 'view:sun_elevation': 59.539593405800005, 's2:degraded_msi_data_percentage': 0, 's2:nodata_pixel_percentage': 0, 's2:saturated_defective_pixel_percentage': 0, 's2:dark_features_percentage': 0.075959, 's2:cloud_shadow_percentage': 0.025365, 's2:vegetation_percentage': 21.364066, 's2:not_vegetated_percentage': 78.196752, 's2:water_percentage': 0.179276, 's2:unclassified_percentage': 0.142106, 's2:medium_proba_clouds_percentage': 0.010524, 's2:high_proba_clouds_percentage': 0.005949, 's2:thin_cirrus_percentage': 0, 's2:snow_ice_percentage': 0, 's2:product_type': 'S2MSI2A', 's2:processing_baseline': '05.09', 's2:product_uri': 'S2A_MSIL2A_20230908T012721_N0509_R131_T53LKF_20230908T055201.SAFE', 's2:generation_time': '2023-09-08T05:52:01.000000Z', 's2:datatake_id': 'GS2A_20230908T012721_042885_N05.09', 's2:datatake_type': 'INS-NOBS', 's2:datastrip_id': 'S2A_OPER_MSI_L2A_DS_2APS_20230908T055201_S20230908T012719_N05.09', 's2:granule_id': 'S2A_OPER_MSI_L2A_TL_2APS_20230908T055201_A042885_T53LKF_N05.09', 's2:reflectance_conversion_factor': 0.98348680913339, 'datetime': '2023-09-08T01:31:03.482000Z', 's2:sequence': '0', 'earthsearch:s3_path': 's3://sentinel-cogs/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A', 'earthsearch:payload_id': 'roda-sentinel2/workflow-sentinel2-to-stac/71e8347d8a85fc7b213250dd4282717f', 'earthsearch:boa_offset_applied': True, 'processing:software': {'sentinel2-to-stac': '0.1.1'}, 'updated': '2023-09-08T11:50:16.401Z', 'proj:code': 'EPSG:32753'}
# dict_keys(['aot', 'blue', 'coastal', 'granule_metadata', 'green', 'nir', 'nir08', 'nir09', 'red', 'rededge1', 'rededge2', 'rededge3', 'scl', 'swir16', 'swir22', 'thumbnail', 'tileinfo_metadata', 'visual', 'wvp', 'aot-jp2', 'blue-jp2', 'coastal-jp2', 'green-jp2', 'nir-jp2', 'nir08-jp2', 'nir09-jp2', 'red-jp2', 'rededge1-jp2', 'rededge2-jp2', 'rededge3-jp2', 'scl-jp2', 'swir16-jp2', 'swir22-jp2', 'visual-jp2', 'wvp-jp2'])

# %% [markdown]
# To keep track of all the metadata information associated with each of the assets, we can use the to_dict() function to convert the STAC response to a json file.

# %%
import json
with open('test_metadata_json.json', 'w') as f:
    item_dict = item.to_dict()
    json.dump(item_dict, f, indent=2)

# %%
# Open the json metadata
with open('test_metadata_json.json', 'r') as f:
    item_metadata = json.load(f)

# These are the bands that require scale factors applied to them.
bands_to_scale = ['aot', 'blue', 'coastal', 'green', 'nir', 'nir08', 'nir09', 'red', 'rededge1', 
                     'rededge2', 'rededge3', 'swir16', 'swir22', 'wvp']

# These are the other bands that we want, but they do not require scale factors.
other_bands_of_interest = ['scl', 'visual'] 

# Now, we can get the scale factor that needs to be applied to each band like this:
for band in bands_to_scale:
    print(f'BAND: {band}')
    print(f'Scale factor: {item_metadata["assets"][band]["raster:bands"][0]["scale"]}')
    print(f'Offset: {item_metadata["assets"][band]["raster:bands"][0]["offset"]}') 
    print(f'Resolution: {item_metadata["assets"][band]["raster:bands"][0]["spatial_resolution"]}')
    print('--------------')

# %% [markdown]
# ### Examine Asset Structure in AWS S3 Bucket
# Each item (Sentinel-2 scene) has multiple assets (bands). We can examine the assets and the download links to each one in the following code block. This also indicates the structure of the data and how it is stored in the source S3 bucket.

# %%
# Set some bands of interest to examine.
bands_of_interest = ['blue', 'green', 'red', 'granule_metadata', 'tileinfo_metadata', 'json_metadata']

items = query.item_collection()

for item in list(items):
    print(f"Examining scene: {item.id}")
    print(f"Available assets: {item.assets.keys()}")

    for band in bands_of_interest:
        if band in item.assets:
            print(f"Band: {band}")
            asset = item.assets[band]
            print(asset.href)

# %% [markdown]
# ### Visualize STAC Results
# We can optionally choose to visualize the Sentinel-2 scenes returned by our query. Code snippets from: https://odc-stac.readthedocs.io/en/latest/notebooks/stac-load-e84-aws.html
#
# In this case, we can see that the scenes returned are from three separate tiles that overlap slightly. It is also important to remember that the STAC query has returned any scene that overlaps even slightly with our AOI (displayed on the map in red below), so we are transferring full Sentinel-2 scenes to our bucket, and we will do the clipping to the AOI boundary during the processing step later on.

# %%
import folium
import shapely.geometry
from branca.element import Figure
import geopandas as gpd
import json  # For reading the GeoJSON file

# Load your existing data
gdf = gpd.GeoDataFrame.from_features(stac_json, "epsg:4326")

# Compute granule id from components
gdf["granule"] = (
    gdf["mgrs:utm_zone"].apply(lambda x: f"{x:02d}")
    + gdf["mgrs:latitude_band"]
    + gdf["mgrs:grid_square"]
)

# Load the AOI GeoJSON file
with open('aois/Kakadu_National_Park.geojson', 'r') as f:
    aoi_geojson = json.load(f)

def convert_bounds(bbox, invert_y=False):
    x1, y1, x2, y2 = bbox
    if invert_y:
        y1, y2 = y2, y1
    return ((y1, x1), (y2, x2))

fig = Figure(width="400px", height="500px")
map1 = folium.Map()
fig.add_child(map1)

# Add the AOI GeoJSON to the map
folium.GeoJson(
    aoi_geojson,
    name="AOI Boundary",
    style_function=lambda x: dict(
        fill=True,
        fillColor='red',
        fillOpacity=0.2,
        weight=2,
        opacity=1,
        color='red'
    ),
).add_to(map1)

# Add your STAC data exploration layer
gdf.explore(
    "granule",
    categorical=True,
    tooltip=[
        "granule",
        "datetime",
        "eo:cloud_cover",
    ],
    popup=True,
    style_kwds=dict(fillOpacity=0.1, width=2),
    name="Scenes Returned ",
    m=map1,
)

map1.fit_bounds(bounds=convert_bounds(gdf.unary_union.bounds))

# Add layer control to toggle between layers
folium.LayerControl().add_to(map1)

display(fig)
# Out:
# /var/folders/fx/sjjzl8vn6nx36srv2y46mn_m0000gn/T/ipykernel_20217/2378216881.py:60: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   map1.fit_bounds(bounds=convert_bounds(gdf.unary_union.bounds))
# /opt/homebrew/anaconda3/envs/aws-stac/lib/python3.13/site-packages/shapely/set_operations.py:421: RuntimeWarning: invalid value encountered in unary_union
#   return lib.unary_union(collections, **kwargs)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1afba6c115010c6a857896643303036 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend granule&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;granule&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;52LHM&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;53LKF&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;53LKG&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1afba6c115010c6a857896643303036&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1afba6c115010c6a857896643303036 = L.map(
#                 &quot;map_f1afba6c115010c6a857896643303036&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d553936c6bceca7cba2e890d126983d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f1afba6c115010c6a857896643303036);
#
#
#         function geo_json_7459d0edd1a29bb523ae5d66236954d6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_7459d0edd1a29bb523ae5d66236954d6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7459d0edd1a29bb523ae5d66236954d6 = L.geoJson(null, {
#                 onEachFeature: geo_json_7459d0edd1a29bb523ae5d66236954d6_onEachFeature,
#
#                 style: geo_json_7459d0edd1a29bb523ae5d66236954d6_styler,
#         });
#
#         function geo_json_7459d0edd1a29bb523ae5d66236954d6_add (data) {
#             geo_json_7459d0edd1a29bb523ae5d66236954d6
#                 .

# %% [markdown]
# ## Transfer to S3 Bucket
#
# To access the data, we can transfer the data from the source S3 bucket to our own S3 bucket. I have set up a bucket for testing called 'cs-awsopendata-sentinel2'.

# %%
import boto3
from urllib.parse import urlparse

def s3_to_s3_copy(source_url, destination_bucket='cs-awsopendata-sentinel2', prefix=''):
    # Parse the source URL to extract bucket and key.
    parsed_url = urlparse(source_url)
    
    # The source_url is in this format: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HL/2023/1/S2B_52LHL_20230106_0_L2A/B02.tif
    url_parts = parsed_url.netloc.split('.') 
    
    # Source bucket should be 'sentinel-cogs' - the first part source url
    source_bucket = url_parts[0]
    
    # Source key is everything after the slash - e.g. 'sentinel-s2-l2a-cogs/52/L/HL/2023/1/S2B_52LHL_20230106_0_L2A/B02.tif'
    source_key = parsed_url.path.lstrip('/')

    # Construct destination key to match the source key. NOTE - can adjust destination_key as necessary.
    destination_key = f"{prefix}{source_key}"
    
    print(f"Copying from bucket: {source_bucket}, key: {source_key}")
    print(f"To bucket: {destination_bucket}, key: {destination_key}")
    
    # Initialize S3 client (region of the sentinel-cog bucket is us-west-2)
    s3 = boto3.client('s3', region_name='us-west-2')  # Specify region if needed
    
    try:
        response = s3.copy_object(
            CopySource={'Bucket': source_bucket, 'Key': source_key},
            Bucket=destination_bucket,
            Key=destination_key,
            RequestPayer='requester'
        )
        print(f"Copy successful: {response}")
        return destination_key
    
    except Exception as e:
        print(f"Error copying object: {e}")
        return None

# %% [markdown]
# In order to be able to properly process the files later and pass on information to end users, we also need to copy the metadata (included in the response to the STAC query) to our S3 bucket. The function below copies the metadata information for each 'item' (i.e. for each unique Sentinel-2 scene), which includes metadata properties for each band, such as the scale factor and offset values to apply to the rasters before they can be used for analysis.

# %%
# TODO: should this be saved locally? be stored in memory and copied directly to S3? 
def export_metadata_json(item, out_path):
    with open(out_path, 'w') as f:
        item_dict = item.to_dict()
        json.dump(item_dict, f, indent=2)
        print(f"Metadata JSON saved to {out_path}")
    return

# %% [markdown]
# Run the function to copy the data returned from our previous query into our S3 bucket.

# %%
# These are the bands that require scale factors applied to them.
bands_of_interest = ['aot', 'blue', 'coastal', 'green', 'nir', 'nir08', 'nir09', 'red', 'rededge1', 
                     'rededge2', 'rededge3', 'swir16', 'swir22', 'wvp', 'scl', 'visual']

destination_bucket = 'cs-awsopendata-sentinel2'
prefix = 'kakadu-three-scenes/'


for item in query.item_collection():
    scene_id = item.id
    print(f"Processing scene: {scene_id}")
    
    metadata_json_path = f"{scene_id}_metadata.json"
    export_metadata_json(item, metadata_json_path)
    
    for band in bands_of_interest:
        if band in item.assets:
            asset = item.assets[band]
            source_url = asset.href
            
            print(f"Copying {band} band from {source_url}")
            destination_key = s3_to_s3_copy(source_url, destination_bucket, prefix)
            
            if destination_key:
                print(f"Successfully copied to s3://{destination_bucket}/{destination_key}")
            else:
                print(f"Failed to copy {band} band from {scene_id}")
# Out:
# Processing scene: S2A_52LHM_20230918_0_L2A
# Metadata JSON saved to S2A_52LHM_20230918_0_L2A_metadata.json
# Copying aot band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/AOT.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/AOT.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/AOT.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'WSGTM824G79SQ6JW', 'HostId': 'J7uP2RDtBgEi++m8QFSL+fdF+j0fpD9gSKFny8liUwyuJAO/GE8niZ3K4CPCyF3dmf09icau/Hw=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'J7uP2RDtBgEi++m8QFSL+fdF+j0fpD9gSKFny8liUwyuJAO/GE8niZ3K4CPCyF3dmf09icau/Hw=', 'x-amz-request-id': 'WSGTM824G79SQ6JW', 'date': 'Mon, 19 May 2025 07:14:19 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"709254644d76ae2a9313879e2cd38672"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 19, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'E/ZXAgybpSU='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/AOT.tif
# Copying blue band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B02.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B02.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B02.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'WSGMFK3DMP4CM4KQ', 'HostId': '72g2XwhVFv3B1+AH5YRAL2m7d1Vb3FdRoxTVnJ1Put0VS9jvZDYLtmTSaRbAB2KlipDRWmHbvEk=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '72g2XwhVFv3B1+AH5YRAL2m7d1Vb3FdRoxTVnJ1Put0VS9jvZDYLtmTSaRbAB2KlipDRWmHbvEk=', 'x-amz-request-id': 'WSGMFK3DMP4CM4KQ', 'date': 'Mon, 19 May 2025 07:14:19 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"f4c6c21325f94c85e0d879b0a5af14d4"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 19, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'OAYeq9Pm45A='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B02.tif
# Copying coastal band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B01.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B01.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B01.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'S7H590PG16MYD7R4', 'HostId': 'osgDcAJ3aeDCnN7wX1SRY8UHvvunK/CPxbLzLCYwOMdKpCREfNUAGNkxU9xtUv3EW046Q+uTxTYzieGi8cQJMw==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'osgDcAJ3aeDCnN7wX1SRY8UHvvunK/CPxbLzLCYwOMdKpCREfNUAGNkxU9xtUv3EW046Q+uTxTYzieGi8cQJMw==', 'x-amz-request-id': 'S7H590PG16MYD7R4', 'date': 'Mon, 19 May 2025 07:14:27 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"3ba23344d27445185db4ef62187b83d3"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 27, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'LSfRPwLI4hg='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B01.tif
# Copying green band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B03.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B03.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B03.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '9G65QTGNN96P12N3', 'HostId': 'gVW9+JdEworbZmk6p4GITGeMa8MJA2ivO6uVuyVWNEzbWk01TqzFctjV7MYeNx3MvcejVxz5yLdSwoj29J6YDg==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'gVW9+JdEworbZmk6p4GITGeMa8MJA2ivO6uVuyVWNEzbWk01TqzFctjV7MYeNx3MvcejVxz5yLdSwoj29J6YDg==', 'x-amz-request-id': '9G65QTGNN96P12N3', 'date': 'Mon, 19 May 2025 07:14:28 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"71f0374d83e70d5884f2e8f9de15e65d"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 28, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'rWwAh64Xhhk='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B03.tif
# Copying nir band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B08.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B08.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B08.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '1W5V0QCY8DM2CBV2', 'HostId': 'bSDkKLthN6xsGLG8K3nXRN6T6TonmXztw+bXvq95F3GvjPgrKA4S845pITYX62xN1Dh87+2qW1I=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'bSDkKLthN6xsGLG8K3nXRN6T6TonmXztw+bXvq95F3GvjPgrKA4S845pITYX62xN1Dh87+2qW1I=', 'x-amz-request-id': '1W5V0QCY8DM2CBV2', 'date': 'Mon, 19 May 2025 07:14:36 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"d936d10f579558ae1ba442041fc3f46c"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 36, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'QRlywUzET1M='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B08.tif
# Copying nir08 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B8A.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B8A.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B8A.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'EVJTJ7Q0PF7EE5ND', 'HostId': 'YX2HEElo7bJNAiyipXJ4JDaYklyy272vMVXuWPKOn/i49qiP9vVL/ZKkmBfNvtfzVYIVVAIpJ6c=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'YX2HEElo7bJNAiyipXJ4JDaYklyy272vMVXuWPKOn/i49qiP9vVL/ZKkmBfNvtfzVYIVVAIpJ6c=', 'x-amz-request-id': 'EVJTJ7Q0PF7EE5ND', 'date': 'Mon, 19 May 2025 07:14:43 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"4af4b528164995e2f6a56da9b0339553"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 43, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'xVu2feVQAL0='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B8A.tif
# Copying nir09 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B09.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B09.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B09.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'B0KTY1G82TF6NZBQ', 'HostId': 'J/g6cq3JdaqhUJ1FwOaYHzWWIC3lKfV7KY0GUrnHzQLzcYtd+84dLYPMoJMrmnISOfKtDeizif8=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'J/g6cq3JdaqhUJ1FwOaYHzWWIC3lKfV7KY0GUrnHzQLzcYtd+84dLYPMoJMrmnISOfKtDeizif8=', 'x-amz-request-id': 'B0KTY1G82TF6NZBQ', 'date': 'Mon, 19 May 2025 07:14:46 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"6ba45e5c117bb1f31868c9e626334f2d"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 46, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'K0UqZZ94asw='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B09.tif
# Copying red band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B04.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B04.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B04.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '3KEQ10X34J6F1P08', 'HostId': 'lYM/9zXvzzGigbALMM2cB2zvItdxzotQvrZ+cO9uvH/9C78RP2fqTM3zvXSKQKiedHFcmcmERpg=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'lYM/9zXvzzGigbALMM2cB2zvItdxzotQvrZ+cO9uvH/9C78RP2fqTM3zvXSKQKiedHFcmcmERpg=', 'x-amz-request-id': '3KEQ10X34J6F1P08', 'date': 'Mon, 19 May 2025 07:14:47 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"af191b3feb437d8d1cac4adfdd248d93"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 47, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'CeVqULnxkhw='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B04.tif
# Copying rededge1 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B05.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B05.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B05.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'C652GS6HCWK4HTPG', 'HostId': 'R/jPjKqULHO+ct1oIVi+rpiFUTRXALhhpKU0Vk+nHfcKIpln8NSFw1rCJCzmqbNZc/NYIgOw63Y=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'R/jPjKqULHO+ct1oIVi+rpiFUTRXALhhpKU0Vk+nHfcKIpln8NSFw1rCJCzmqbNZc/NYIgOw63Y=', 'x-amz-request-id': 'C652GS6HCWK4HTPG', 'date': 'Mon, 19 May 2025 07:14:54 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"2f3ab50b391c75a448edcff2e904fb80"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 54, tzinfo=tzutc()), 'ChecksumCRC64NVME': '0t9gPU4YALo='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B05.tif
# Copying rededge2 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B06.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B06.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B06.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'FWD2E94TY1F041C9', 'HostId': 'plq7ZpKOkiL0lOgo4rYs/YRYIFJLxSl7EX0wvtwruWHDf0M1Si03XQpONV3JIjTN2IYJEwMcFJokVBSfVZ37tw==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'plq7ZpKOkiL0lOgo4rYs/YRYIFJLxSl7EX0wvtwruWHDf0M1Si03XQpONV3JIjTN2IYJEwMcFJokVBSfVZ37tw==', 'x-amz-request-id': 'FWD2E94TY1F041C9', 'date': 'Mon, 19 May 2025 07:14:56 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"4f6a40cef5cbe74e25a61240e4b521f8"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 56, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'U6Nf43EKIbY='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B06.tif
# Copying rededge3 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B07.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B07.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B07.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '5DT9ZWVEXXY6MMSD', 'HostId': '2J9wKKi/CvGdkwH6SZAhMD1nPWA7Mrw6gmvemNwMnXLaRTveMIm2+3pYDqOHSROnsflEtUDozdo=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '2J9wKKi/CvGdkwH6SZAhMD1nPWA7Mrw6gmvemNwMnXLaRTveMIm2+3pYDqOHSROnsflEtUDozdo=', 'x-amz-request-id': '5DT9ZWVEXXY6MMSD', 'date': 'Mon, 19 May 2025 07:14:59 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"28cdb13b937f0593c5ebb1670fbb0c4f"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 14, 59, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'GH/lremQqQw='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B07.tif
# Copying swir16 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B11.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B11.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B11.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'S4EZHQZS9R146N2P', 'HostId': '274zEXVG7EMp7OPfjHQUxzezplooqVO0QKQr3LF8/JEEHUEVkV6SXCgUzN6x9zZdD8KpBCuNFZU=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '274zEXVG7EMp7OPfjHQUxzezplooqVO0QKQr3LF8/JEEHUEVkV6SXCgUzN6x9zZdD8KpBCuNFZU=', 'x-amz-request-id': 'S4EZHQZS9R146N2P', 'date': 'Mon, 19 May 2025 07:15:01 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"d156b4248cad699b89cf2eb422bcfa2f"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 1, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'tuKVO+a3mOI='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B11.tif
# Copying swir22 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B12.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B12.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B12.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'C2466A24VFJXMWP1', 'HostId': 'vzCb3sB/LbtaQqXYzOqjaza35txsjCHZqojh8Ks9AsMNG/KEohGSRaaJVO+FOyXyOM9jXFkWdnM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'vzCb3sB/LbtaQqXYzOqjaza35txsjCHZqojh8Ks9AsMNG/KEohGSRaaJVO+FOyXyOM9jXFkWdnM=', 'x-amz-request-id': 'C2466A24VFJXMWP1', 'date': 'Mon, 19 May 2025 07:15:03 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"404971d4003ff0d0c5260879034b4def"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 3, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'Ku6yrbcKPuI='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B12.tif
# Copying wvp band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/WVP.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/WVP.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/WVP.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'T5K1T2TSY1580MJP', 'HostId': 'X644ojoNT0cXNCcBl92Y/Pn24zL8CLFc05OE/+ZV6O603556mudM8qQ2XtzsX0vd9Y5xISXNhAf1ZRmia9x77w==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'X644ojoNT0cXNCcBl92Y/Pn24zL8CLFc05OE/+ZV6O603556mudM8qQ2XtzsX0vd9Y5xISXNhAf1ZRmia9x77w==', 'x-amz-request-id': 'T5K1T2TSY1580MJP', 'date': 'Mon, 19 May 2025 07:15:06 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"4ffd454cdcb8a1334af4a599f20e97c6"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 6, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'SjeoQ3Qc02A='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/WVP.tif
# Copying scl band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/SCL.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/SCL.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/SCL.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '8G6T7W641PQMHMV2', 'HostId': 'r1ncCUxgNEFmv5JeKTk4Vc594carLnpwixUmQPGOuUgu4sh9blRywscbvi96YkruBCPUr7K/7hM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'r1ncCUxgNEFmv5JeKTk4Vc594carLnpwixUmQPGOuUgu4sh9blRywscbvi96YkruBCPUr7K/7hM=', 'x-amz-request-id': '8G6T7W641PQMHMV2', 'date': 'Mon, 19 May 2025 07:15:08 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"b84028d9b337e992681124fad6cdd04b"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 8, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'Qxi4+U0KT4Y='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/SCL.tif
# Copying visual band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/TCI.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/TCI.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/TCI.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'TAQT9CZ430YQ3V88', 'HostId': '3zxsEIFSOuK5+3TSvphbYFgcdYEkDnbswd3+rBtPRWKyI21XkIJCe1Z3EIBbErFjKsEUmgBdXQFo0UbHJbnSlg==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '3zxsEIFSOuK5+3TSvphbYFgcdYEkDnbswd3+rBtPRWKyI21XkIJCe1Z3EIBbErFjKsEUmgBdXQFo0UbHJbnSlg==', 'x-amz-request-id': 'TAQT9CZ430YQ3V88', 'date': 'Mon, 19 May 2025 07:15:09 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"3ec63c51880949a6d8c13c2cf93d849d"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 9, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'afgutna/nCI='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/TCI.tif
# Processing scene: S2A_53LKG_20230918_0_L2A
# Metadata JSON saved to S2A_53LKG_20230918_0_L2A_metadata.json
# Copying aot band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/AOT.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/AOT.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/AOT.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'TGGG1R3FK76Q2SVH', 'HostId': '45JfNM2zbCvHvlvrjEJZI3DsrG5ns36A3H2KsYM+UK0P1fC/CD4vVjqKZgRCmN1DZCTbJ8Xc4f53FO0e7eXPoMliA9OJ/sA4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '45JfNM2zbCvHvlvrjEJZI3DsrG5ns36A3H2KsYM+UK0P1fC/CD4vVjqKZgRCmN1DZCTbJ8Xc4f53FO0e7eXPoMliA9OJ/sA4', 'x-amz-request-id': 'TGGG1R3FK76Q2SVH', 'date': 'Mon, 19 May 2025 07:15:21 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"21d40ba0d53f72999295b7cf04b3137d"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 21, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'D3a8ma3ihQU='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/AOT.tif
# Copying blue band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B02.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B02.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B02.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'TGGVT1FT31AHR263', 'HostId': 'DwfOGQonjaHQXX/e4EvOybP/CZ33j8bVFSUFdMkAfawIkkS3boPF7lVk8tvhPmD6M/JTvXqUvgiltuRC9hk4BlY8FNxkScTQ', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'DwfOGQonjaHQXX/e4EvOybP/CZ33j8bVFSUFdMkAfawIkkS3boPF7lVk8tvhPmD6M/JTvXqUvgiltuRC9hk4BlY8FNxkScTQ', 'x-amz-request-id': 'TGGVT1FT31AHR263', 'date': 'Mon, 19 May 2025 07:15:21 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"708e4a2d7366e49dae8f6559765a855d"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 21, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'Mx7Ppd7267k='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B02.tif
# Copying coastal band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B01.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B01.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B01.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'A2F8Q38J3S0HQZFS', 'HostId': 'G6Nf2G5lkC5tURUiox4bo/HEJMbwObUXYUOsVLgZtOBVYr2xqJm6o2DORcwZ8KkjChbVB3dbB40=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'G6Nf2G5lkC5tURUiox4bo/HEJMbwObUXYUOsVLgZtOBVYr2xqJm6o2DORcwZ8KkjChbVB3dbB40=', 'x-amz-request-id': 'A2F8Q38J3S0HQZFS', 'date': 'Mon, 19 May 2025 07:15:34 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"5a51867d6cd3f046dd62be61398f13fb"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 34, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'HA+9hjIdDHU='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B01.tif
# Copying green band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B03.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B03.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B03.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'PMS2VZYKZ3NRTZRJ', 'HostId': 'woMuwi269kxXSxTyx8EO7tDGa5rzypqFR08yNY8AUiHMkNFzFr/p2e/oWGeL+0mhnhXrrbrXxy7Uy/dHM1N5hw==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'woMuwi269kxXSxTyx8EO7tDGa5rzypqFR08yNY8AUiHMkNFzFr/p2e/oWGeL+0mhnhXrrbrXxy7Uy/dHM1N5hw==', 'x-amz-request-id': 'PMS2VZYKZ3NRTZRJ', 'date': 'Mon, 19 May 2025 07:15:35 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"204f57dfe988f153aa2692ad861a3ea3"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 35, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'jky5Kcmr2JQ='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B03.tif
# Copying nir band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B08.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B08.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B08.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'AA2G4881FNQJVKR2', 'HostId': '3pDwY4nw40PPPZ30ekm8bwHqliosDD9uu6DLPAdGrywZvRtdk2Hzr82r4UlgN+1GCXDH8Ox6hG0=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '3pDwY4nw40PPPZ30ekm8bwHqliosDD9uu6DLPAdGrywZvRtdk2Hzr82r4UlgN+1GCXDH8Ox6hG0=', 'x-amz-request-id': 'AA2G4881FNQJVKR2', 'date': 'Mon, 19 May 2025 07:15:44 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"2189b90550b9348ce6211cd1b11f948a"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 44, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'vldGGX1Tt+I='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B08.tif
# Copying nir08 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B8A.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B8A.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B8A.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'VZ1TV761VZPJ21NJ', 'HostId': 'ODyf2apPV8zaPi0KSSthEwzkqWSYYmgnTw7Q0Qlyjum5b+INH06ekLsSNqpHahcptTfMXmqMOjg=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'ODyf2apPV8zaPi0KSSthEwzkqWSYYmgnTw7Q0Qlyjum5b+INH06ekLsSNqpHahcptTfMXmqMOjg=', 'x-amz-request-id': 'VZ1TV761VZPJ21NJ', 'date': 'Mon, 19 May 2025 07:15:51 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"826b7e8901d04bb24e3920685f96eb91"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 51, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'JZBeDnu0KBY='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B8A.tif
# Copying nir09 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B09.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B09.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B09.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'F78M2YKGCT83C5D9', 'HostId': 'yrz8UakbAzZzP5bfutp2Rv6hajk7FpE//6qZ353/gOFLc3Q4hS5BwwqgEs4QT7/ipgbBZ6wpfl0=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'yrz8UakbAzZzP5bfutp2Rv6hajk7FpE//6qZ353/gOFLc3Q4hS5BwwqgEs4QT7/ipgbBZ6wpfl0=', 'x-amz-request-id': 'F78M2YKGCT83C5D9', 'date': 'Mon, 19 May 2025 07:15:54 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"b98c956b49936417fc367fe90c927374"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 54, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'SbeyB7bdgqs='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B09.tif
# Copying red band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B04.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B04.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B04.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'VYDSQ1JFNXH4H24T', 'HostId': 'mnxjwoRtDo7fR+nwhZd7ayKjZ3J5y0DOHCZuAZ3WskolbS3/QI7pndJVPO1INKYHGkzysIFNYCU=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'mnxjwoRtDo7fR+nwhZd7ayKjZ3J5y0DOHCZuAZ3WskolbS3/QI7pndJVPO1INKYHGkzysIFNYCU=', 'x-amz-request-id': 'VYDSQ1JFNXH4H24T', 'date': 'Mon, 19 May 2025 07:15:55 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"0f41d23b1632cfed45238bf06ed86c69"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 15, 55, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'odx8Wkoz+cA='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B04.tif
# Copying rededge1 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B05.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B05.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B05.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'NJAMKDFWJ4R28WQC', 'HostId': 'cW2sa3xeN+WA5UGnwYjHDVp0RtqRYBNOYGsms84nKY7oYCcitF63ghKxbRG9KdQi0bXY0KDd3wGoZPI0QqvBbA==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'cW2sa3xeN+WA5UGnwYjHDVp0RtqRYBNOYGsms84nKY7oYCcitF63ghKxbRG9KdQi0bXY0KDd3wGoZPI0QqvBbA==', 'x-amz-request-id': 'NJAMKDFWJ4R28WQC', 'date': 'Mon, 19 May 2025 07:16:03 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"a7389f0e4287a28765ce80e572f88bf3"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 3, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'QN73gQW5yHg='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B05.tif
# Copying rededge2 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B06.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B06.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B06.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'MDQ8KAGY3C533JH7', 'HostId': 'QFI4AoAfmWPnuCSZ/Ng3arYBBRGvwOoE57NEqYaP+LMx9OWD0Vhucn1F95ev2EauEVqRY/62KxRdRCpzbCrUIA==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'QFI4AoAfmWPnuCSZ/Ng3arYBBRGvwOoE57NEqYaP+LMx9OWD0Vhucn1F95ev2EauEVqRY/62KxRdRCpzbCrUIA==', 'x-amz-request-id': 'MDQ8KAGY3C533JH7', 'date': 'Mon, 19 May 2025 07:16:05 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"da5f261923fc46db598381e861a460d0"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 5, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'wf0uMGX0Xso='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B06.tif
# Copying rededge3 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B07.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B07.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B07.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'H9RZXZP054BFT6GK', 'HostId': 'KD0Ijk7a9hK1K6YSqBKAhRSKfOw3D+lk0xRQ9m6V3qqEcWabWiuzPSFTkD+6nq4iWZJRPFL4pCzsiQreI+x9GA==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'KD0Ijk7a9hK1K6YSqBKAhRSKfOw3D+lk0xRQ9m6V3qqEcWabWiuzPSFTkD+6nq4iWZJRPFL4pCzsiQreI+x9GA==', 'x-amz-request-id': 'H9RZXZP054BFT6GK', 'date': 'Mon, 19 May 2025 07:16:09 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"3ce11c1c5d1569adcbe853dc3c886392"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 9, tzinfo=tzutc()), 'ChecksumCRC64NVME': '/jr9gxPUuNA='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B07.tif
# Copying swir16 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B11.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B11.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B11.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'QZ4TW72AVM8RMCSQ', 'HostId': 'Pww2l1wlX3HYDiL+ZMIQfgfp9sqGC1bQ1ZbbCqL1OBtWnLBrwqBElco+eC+3l0lgiencOG4Xf6M=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Pww2l1wlX3HYDiL+ZMIQfgfp9sqGC1bQ1ZbbCqL1OBtWnLBrwqBElco+eC+3l0lgiencOG4Xf6M=', 'x-amz-request-id': 'QZ4TW72AVM8RMCSQ', 'date': 'Mon, 19 May 2025 07:16:12 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"19aa662cfde38f741adc1d9b3f0f3fbc"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 12, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'LNnt254qgeQ='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B11.tif
# Copying swir22 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B12.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B12.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B12.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'P957Y2DED8X0PEB0', 'HostId': '0twZGPKutJHfNSsJiOnfBHN9uiodJb00XRyl8bd4f/ycvb/wjE1jON6ghkqB0BB21qP1IAatjtME8uHqMF2sZA==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '0twZGPKutJHfNSsJiOnfBHN9uiodJb00XRyl8bd4f/ycvb/wjE1jON6ghkqB0BB21qP1IAatjtME8uHqMF2sZA==', 'x-amz-request-id': 'P957Y2DED8X0PEB0', 'date': 'Mon, 19 May 2025 07:16:15 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"2b3f8d696954fbd667cdc486ff57f0c9"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 15, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'LzpEsgL4QTI='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/B12.tif
# Copying wvp band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/WVP.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/WVP.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/WVP.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '9PBDVQ44P6VS6BWT', 'HostId': 'yjFQQ6EGMbHKrnNcC/wJ5JUeX3ZWg4PIh4nZ7i6OWI7f4x1s1rVw79azBdP0xAOOtqGtSaDDsYU=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'yjFQQ6EGMbHKrnNcC/wJ5JUeX3ZWg4PIh4nZ7i6OWI7f4x1s1rVw79azBdP0xAOOtqGtSaDDsYU=', 'x-amz-request-id': '9PBDVQ44P6VS6BWT', 'date': 'Mon, 19 May 2025 07:16:19 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"4a1ca22de6014058ca7fe51f2283a7d1"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 19, tzinfo=tzutc()), 'ChecksumCRC64NVME': '5O10MOT9/A4='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/WVP.tif
# Copying scl band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/SCL.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/SCL.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/SCL.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'G0SV8WWMPCQASEMG', 'HostId': 'lHaAAmJJhC7FxLE6VUyXdb2O2WP7D9GG3d1FZRQHFT0q1kfitVOVviPDmwMC9wsy/VuBPFPBhDY=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'lHaAAmJJhC7FxLE6VUyXdb2O2WP7D9GG3d1FZRQHFT0q1kfitVOVviPDmwMC9wsy/VuBPFPBhDY=', 'x-amz-request-id': 'G0SV8WWMPCQASEMG', 'date': 'Mon, 19 May 2025 07:16:22 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"7a348531746deecf16bbecf5de328c6a"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 22, tzinfo=tzutc()), 'ChecksumCRC64NVME': '+9bKApAAAlc='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/SCL.tif
# Copying visual band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/TCI.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/TCI.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/TCI.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'G0SWX4W1MEFSXE08', 'HostId': 'rMDaTKEXaHjc6vAm1/PPCJEu3LtaEb6PtA1iyCzdLgeTAJYEaUaxKaXrsEW04mc1wZZ5N0l0Af4=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'rMDaTKEXaHjc6vAm1/PPCJEu3LtaEb6PtA1iyCzdLgeTAJYEaUaxKaXrsEW04mc1wZZ5N0l0Af4=', 'x-amz-request-id': 'G0SWX4W1MEFSXE08', 'date': 'Mon, 19 May 2025 07:16:22 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"c697c4cbb61652e366bbf05c0ae6ed1e"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 22, tzinfo=tzutc()), 'ChecksumCRC64NVME': '0bW0+3vgC3g='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KG/2023/9/S2A_53LKG_20230918_0_L2A/TCI.tif
# Processing scene: S2A_53LKF_20230908_0_L2A
# Metadata JSON saved to S2A_53LKF_20230908_0_L2A_metadata.json
# Copying aot band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/AOT.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/AOT.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/AOT.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '1XY7RNBSJARNWDFK', 'HostId': '2NbR67yj9Z83OOLZGH9Th+gIz4sIArmZ1C8lXvRy9LTm/Tb8qfDVA5FQG0a+JqH3CsprWnO06Lo=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '2NbR67yj9Z83OOLZGH9Th+gIz4sIArmZ1C8lXvRy9LTm/Tb8qfDVA5FQG0a+JqH3CsprWnO06Lo=', 'x-amz-request-id': '1XY7RNBSJARNWDFK', 'date': 'Mon, 19 May 2025 07:16:33 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"5849386b20069bdcc6b62d48a9b0258c"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 33, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'kcP1uaPAIco='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/AOT.tif
# Copying blue band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B02.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B02.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B02.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '1XY1DMYAVS7KW0XJ', 'HostId': 'dUn9zxk3SzeCMklLWbrFhyHpRXWfriItn/DpePJnREcwN+pulVImW25pEiTmsHhHdi+EB+X3Hk0=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'dUn9zxk3SzeCMklLWbrFhyHpRXWfriItn/DpePJnREcwN+pulVImW25pEiTmsHhHdi+EB+X3Hk0=', 'x-amz-request-id': '1XY1DMYAVS7KW0XJ', 'date': 'Mon, 19 May 2025 07:16:33 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"7658828241f6c75be7b8d38a7b49c33c"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 33, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'H3KBHBmS1q4='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B02.tif
# Copying coastal band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B01.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B01.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B01.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '6BEG53XGC0Q29CHT', 'HostId': 'Vi9/+FXdCaINzaf5EOQa3Nq/m+nK2jGjp6CLGdga6kHZtr9s92RkbSTBn5KfZWCvA5w1cWj6yPw3Na1E3SodHg==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Vi9/+FXdCaINzaf5EOQa3Nq/m+nK2jGjp6CLGdga6kHZtr9s92RkbSTBn5KfZWCvA5w1cWj6yPw3Na1E3SodHg==', 'x-amz-request-id': '6BEG53XGC0Q29CHT', 'date': 'Mon, 19 May 2025 07:16:42 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"2a954efbb6658a45c22995ef40b836a8"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 42, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'm4QmubORDfQ='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B01.tif
# Copying green band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B03.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B03.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B03.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'W0WED4KK12N50CYV', 'HostId': 'QdvuckWlX4s7+MZN0KDJF9cvehUbz9FEpZEf2BXe37Yv8w7wmPiwC+Syj4jFGoedjLCTzcaOQT0psfdWxG33WA==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'QdvuckWlX4s7+MZN0KDJF9cvehUbz9FEpZEf2BXe37Yv8w7wmPiwC+Syj4jFGoedjLCTzcaOQT0psfdWxG33WA==', 'x-amz-request-id': 'W0WED4KK12N50CYV', 'date': 'Mon, 19 May 2025 07:16:43 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"188eff6af9aa6cd39b6adb75a3a32d52"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 43, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'ZEc9Wh2ubuc='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B03.tif
# Copying nir band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B08.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B08.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B08.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'WQ52912K350Y9WHX', 'HostId': 'pNPorXoGv0jcEwwBzruoqO3w1g2XhWzYw5w4YTurmfn/QKED+DvS1wWAHyrx/jpJLuRAEbtlB1k=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'pNPorXoGv0jcEwwBzruoqO3w1g2XhWzYw5w4YTurmfn/QKED+DvS1wWAHyrx/jpJLuRAEbtlB1k=', 'x-amz-request-id': 'WQ52912K350Y9WHX', 'date': 'Mon, 19 May 2025 07:16:52 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"7d9b576f218e2dc2996494359b6c7cac"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 16, 52, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'fsy6Ue4pxCg='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B08.tif
# Copying nir08 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B8A.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B8A.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B8A.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '8HRWM462F50BY4RK', 'HostId': 'ZgrTKapVZk9apr7eZGEeljGOQdG/XZAZNwxPuBN5PTOD9wD/Q6/fgbrRDpT/7zui3ZjQe/NFj7X9BvH3T0QRNg==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'ZgrTKapVZk9apr7eZGEeljGOQdG/XZAZNwxPuBN5PTOD9wD/Q6/fgbrRDpT/7zui3ZjQe/NFj7X9BvH3T0QRNg==', 'x-amz-request-id': '8HRWM462F50BY4RK', 'date': 'Mon, 19 May 2025 07:17:00 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"359969d7374abceb7da37a0c41f835d4"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'snFMN/xuffM='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B8A.tif
# Copying nir09 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B09.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B09.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B09.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'B8Q6Q43NE350TJGQ', 'HostId': 'vI+9oGCeC2CYWh6xsI7vKqgIheqxrX8h3JziHtiB0isOtD9lc6a8atws/pHwqhz//DYHPLqJw43QxZed9znPcQ==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'vI+9oGCeC2CYWh6xsI7vKqgIheqxrX8h3JziHtiB0isOtD9lc6a8atws/pHwqhz//DYHPLqJw43QxZed9znPcQ==', 'x-amz-request-id': 'B8Q6Q43NE350TJGQ', 'date': 'Mon, 19 May 2025 07:17:03 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"a04624397e35afad36486939966652dc"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 3, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'HzU7gZAzXq0='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B09.tif
# Copying red band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B04.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B04.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B04.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'S2T6GSQ1WDQG532F', 'HostId': 'URBY4RPZUztrU9/GdwPPrwpvX3YwcQh79ZrRPIpTz+9FxPoLBpvsSNAkc0blS9uPwoRJzW8DatweCSOBHtyKfg==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'URBY4RPZUztrU9/GdwPPrwpvX3YwcQh79ZrRPIpTz+9FxPoLBpvsSNAkc0blS9uPwoRJzW8DatweCSOBHtyKfg==', 'x-amz-request-id': 'S2T6GSQ1WDQG532F', 'date': 'Mon, 19 May 2025 07:17:04 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"c1c6952001ceb995b6f1fc3f03681b0a"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 4, tzinfo=tzutc()), 'ChecksumCRC64NVME': '325oOVCwSWw='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B04.tif
# Copying rededge1 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B05.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B05.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B05.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '1982P0GFW3A10316', 'HostId': 'Se5TVG9sa5YpupKa1xclvetAbtW1FZC8n3I1WyNiYIp4Sf+4g7thlrj+6ToVcW4UhC+SK1ecztI=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Se5TVG9sa5YpupKa1xclvetAbtW1FZC8n3I1WyNiYIp4Sf+4g7thlrj+6ToVcW4UhC+SK1ecztI=', 'x-amz-request-id': '1982P0GFW3A10316', 'date': 'Mon, 19 May 2025 07:17:12 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"85003845b44549944f7c7b0c6da4f462"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 12, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'tN8hVHFySsc='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B05.tif
# Copying rededge2 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B06.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B06.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B06.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'H8P9GFES23AVEQJY', 'HostId': '2m8JOgWa6HiGAKvdlwGXfjEVcKIx8dEGOACnGceF+NF73CQO01aJFCqp/iigEXk0y8/DhFa2pa3QnzCNSq890w==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '2m8JOgWa6HiGAKvdlwGXfjEVcKIx8dEGOACnGceF+NF73CQO01aJFCqp/iigEXk0y8/DhFa2pa3QnzCNSq890w==', 'x-amz-request-id': 'H8P9GFES23AVEQJY', 'date': 'Mon, 19 May 2025 07:17:15 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"b61787e2caeaf8392bf95d96fffa1d52"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 15, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'GNKJJp14QGU='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B06.tif
# Copying rededge3 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B07.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B07.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B07.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'PYVZFWQGKF1NVQ32', 'HostId': 'FhhGyKlHOYaNN7Zz86HvrSqaJ4fN5wq5NXuebqK8KaplwYpfVS6WiwrnJ9tASIdpwlYY/5PB7k8=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'FhhGyKlHOYaNN7Zz86HvrSqaJ4fN5wq5NXuebqK8KaplwYpfVS6WiwrnJ9tASIdpwlYY/5PB7k8=', 'x-amz-request-id': 'PYVZFWQGKF1NVQ32', 'date': 'Mon, 19 May 2025 07:17:18 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"6b3e2eb2870df6fe67b3dd323737b86d"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 18, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'x7N9LhOGYEY='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B07.tif
# Copying swir16 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B11.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B11.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B11.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '38ZGB77RNDWPH43Y', 'HostId': 'crlbggyeB5gDjOYGk2rEPvvbCu+JAbSs5Lq6hInRjOgztuDjWSCgBPYpuMz5YS5kfx3bCZAnG5E=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'crlbggyeB5gDjOYGk2rEPvvbCu+JAbSs5Lq6hInRjOgztuDjWSCgBPYpuMz5YS5kfx3bCZAnG5E=', 'x-amz-request-id': '38ZGB77RNDWPH43Y', 'date': 'Mon, 19 May 2025 07:17:21 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"b5a39fc7eab0a43823b04d3e4471fc15"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 21, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'k80wa88t6U4='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B11.tif
# Copying swir22 band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B12.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B12.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B12.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'HJKPHB25DZSX40QC', 'HostId': 'nSp8CvbZJDTnMuJKslrCFHDgDK7rDqaeJDb6aILt9xiDyli5SC1f5x0BcECIXZIMCbd3Ur4ZcLc=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'nSp8CvbZJDTnMuJKslrCFHDgDK7rDqaeJDb6aILt9xiDyli5SC1f5x0BcECIXZIMCbd3Ur4ZcLc=', 'x-amz-request-id': 'HJKPHB25DZSX40QC', 'date': 'Mon, 19 May 2025 07:17:24 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"02f0d03086f886c11cb4add085509805"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 24, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'JF2K65RaMKI='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/B12.tif
# Copying wvp band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/WVP.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/WVP.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/WVP.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'PP22ZRQ3GKKVHVZS', 'HostId': 'BjpD3XolzUTc7CvAkndrqMatdMFxgW2fYxyv7bOMroOggCg5yyG4uReG/hOS2pf77XA2TbTU5Jg=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'BjpD3XolzUTc7CvAkndrqMatdMFxgW2fYxyv7bOMroOggCg5yyG4uReG/hOS2pf77XA2TbTU5Jg=', 'x-amz-request-id': 'PP22ZRQ3GKKVHVZS', 'date': 'Mon, 19 May 2025 07:17:26 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"39eebaf2e8ca1df8244aa724374518ab"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 26, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'dJiSyhB9M8w='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/WVP.tif
# Copying scl band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/SCL.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/SCL.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/SCL.tif
# Copy successful: {'ResponseMetadata': {'RequestId': '2E9734CCKCV0ZJ6X', 'HostId': 'vkx+Ai9UEcOK/3RYhHe1RsCmeZZRm2BP1BXzuDHFeWDmOPd4nKJ/2N0fSyh+o/jI8TA78yQLSLM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'vkx+Ai9UEcOK/3RYhHe1RsCmeZZRm2BP1BXzuDHFeWDmOPd4nKJ/2N0fSyh+o/jI8TA78yQLSLM=', 'x-amz-request-id': '2E9734CCKCV0ZJ6X', 'date': 'Mon, 19 May 2025 07:17:32 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"da97fbb44722dce24b16c0c59540e2d0"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 32, tzinfo=tzutc()), 'ChecksumCRC64NVME': '5/5UHX9svic='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/SCL.tif
# Copying visual band from https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/TCI.tif
# Copying from bucket: sentinel-cogs, key: sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/TCI.tif
# To bucket: cs-awsopendata-sentinel2, key: kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/TCI.tif
# Copy successful: {'ResponseMetadata': {'RequestId': 'ZTCAMM3JJ2DDAX0F', 'HostId': 'hZMRTBWU4bwOkrsuIEvl8G9DE12wy3U9IcHOM3w7qSDLmhWBHwMYX6KATevuXE8JTYG2gtZXyjLMVZPCyYygtQ==', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'hZMRTBWU4bwOkrsuIEvl8G9DE12wy3U9IcHOM3w7qSDLmhWBHwMYX6KATevuXE8JTYG2gtZXyjLMVZPCyYygtQ==', 'x-amz-request-id': 'ZTCAMM3JJ2DDAX0F', 'date': 'Mon, 19 May 2025 07:17:33 GMT', 'x-amz-server-side-encryption': 'AES256', 'content-type': 'application/xml', 'content-length': '275', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'ServerSideEncryption': 'AES256', 'CopyObjectResult': {'ETag': '"0dec6a75b4e0c950644fbff337fb3156"', 'LastModified': datetime.datetime(2025, 5, 19, 7, 17, 33, tzinfo=tzutc()), 'ChecksumCRC64NVME': 'Bz4SjJejE7U='}}
# Successfully copied to s3://cs-awsopendata-sentinel2/kakadu-three-scenes/sentinel-s2-l2a-cogs/53/L/KF/2023/9/S2A_53LKF_20230908_0_L2A/TCI.tif

# %% [markdown]
# ## Download and visualize the raw data
#
# First we'll download the tifs that are now stored in the cecil science S3 bucket and save them locally for testing processing.

# %%
import boto3
import numpy as np
from pathlib import Path
import os
import re

def download_all_sentinel_bands(bucket_name, prefix, local_base_dir="./sentinel_data"):

    # Initialize S3 client
    s3 = boto3.client('s3')
    
    print(f"Listing objects in bucket '{bucket_name}' with prefix '{prefix}'...")
    
    # Dictionary to store scene IDs and their downloaded files
    downloaded_files = {}
    
    # Get all objects in the specified subdirectory ('prefix')
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, MaxKeys=100)
    
    for obj in response['Contents']:
        key = obj['Key']
        
        # Extract scene ID from the path (pattern: .../sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B02.tif)
        match = re.search(r'/(S2[AB]_\d+[A-Z]+_\d+_\d+_L\d+[A-Z])/', key)
        if not match:
            print(f"Could not extract scene ID from path: {key}")
            continue
        # Extract scene ID and filename.
        scene_id = match.group(1)
        filename = os.path.basename(key)
        
        # Create directory for this scene.
        scene_dir = os.path.join(local_base_dir, scene_id)
        Path(scene_dir).mkdir(parents=True, exist_ok=True)
        
        # Download the file
        local_path = os.path.join(scene_dir, filename)
        
        print(f"Downloading {key} to {local_path}")
        s3.download_file(bucket_name, key, local_path)
        
        # Update the downloaded files dictionary
        if scene_id not in downloaded_files:
            downloaded_files[scene_id] = []
        downloaded_files[scene_id].append(local_path)
    
    # Print summary
    print("\nDownload Summary:")
    for scene_id, files in downloaded_files.items():
        print(f"  Scene: {scene_id}")
        print(f"    - Downloaded {len(files)} files")
    
    return downloaded_files

# %%
    # Bucket and subdirectory within bucket from which to download data.
    bucket_name = "cs-awsopendata-sentinel2"
    prefix = "kakadu-rgb-test/"
    
    # Download the files for all the bands in the 'prefix' folder.
    print(f"Downloading all band files from {bucket_name}/{prefix}...")
    downloaded_scenes = download_all_sentinel_bands(
        bucket_name=bucket_name,
        prefix=prefix,
        local_base_dir="./sentinel_data" # Specify where to save the files locally. 
    )

# %%
import rasterio
import matplotlib.pyplot as plt

for scene_id, files in downloaded_scenes.items():
    print(f"Scene ID: {scene_id}")

    # Set up three subplots for the three bands
    fig, axs = plt.subplots(1, len(files), figsize=(15, 5))

    for i in range(len(files)):
        with rasterio.open(files[i]) as src:
            print(f"  - CRS: {src.crs}")
            print(f"  - Width: {src.width}, Height: {src.height}")
            print(f"  - Bounds: {src.bounds}")

            axs[i].set_title(f"{files[i]}")
            axs[i].imshow(src.read(1), cmap='gray')

# %% [markdown]
# ## Examine Scale and Offset Metadata

# %%
# import rioxarray

# test_band = rioxarray.open_rasterio('https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/52/L/HM/2023/9/S2A_52LHM_20230918_0_L2A/B02.tif')
# print(test_band)

# %% [markdown]
# ## Process the data into a DataFrame

# %%
import rasterio.features
import rasterio.mask
import pandas as pd
import numpy as np

def create_geom_mask(src, geom):
    return rasterio.features.geometry_mask(
        geometries=[geom],
        transform=src.transform,
        all_touched=True,
        out_shape=(src.height, src.width),
    )

def load_geojson_as_geom(geojson_path, target_crs=None):
    gdf = gpd.read_file(geojson_path)
    if target_crs:
        gdf = gdf.to_crs(target_crs)
    return gdf.geometry.iloc[0]

def get_pixel_boundary_wkt(dataset, row, col):
    points = [
        dataset.xy(row, col, offset=offset) for offset in ["ul", "ll", "lr", "ur", "ul"]
    ]

    return "POLYGON ((" + ", ".join(f"{x} {y}" for x, y in points) + "))"

def process_s2(dataset, geojson_path):
    """Original process() function from parse_geotiff.py - just removed
    position, which wasn't used for local testing."""
    
    crs = str(dataset.crs)

    geom = load_geojson_as_geom(geojson_path, target_crs=crs)

    geom_mask = create_geom_mask(dataset, geom)
    
    results = []

    for band_index in range(1, dataset.count + 1):

        raster_band = dataset.read(band_index, masked=True)

        for raster_row in range(0, dataset.height):
            for raster_col in range(0, dataset.width):

                # Skip pixels outside the geometry
                if geom_mask[raster_row][raster_col]:
                    continue

                if raster_band.mask[raster_row][raster_col]:
                    value = None
                else:
                    value = float(raster_band.data[raster_row][raster_col])

                x, y = dataset.xy(raster_row, raster_col, offset="center")
                
                pixel_boundary = get_pixel_boundary_wkt(dataset, raster_row, raster_col)
                
                results.append({
                    'relative_path': dataset.name.split('/')[-2:],
                    'crs': crs,
                    'x': x,
                    'y': y,
                    'boundary_wkt': pixel_boundary,
                    'band_index': band_index,
                    'value': value
                })
    
    return pd.DataFrame(results)

# %%
s2_band = "/Users/sabinenix/Documents/Code/sentinel-2-pipeline/aws/sentinel_data/S2A_52LHM_20230918_0_L2A/B02.tif"
geojson_path = "/Users/sabinenix/Documents/Data/AOIs/Kakadu_National_Park.geojson"

with rasterio.open(s2_band) as src:
    s2_band_results = process_s2(src, geojson_path)

# %%
s2_band_results.head(5)

# %%
from shapely import wkt
import geopandas as gpd
import matplotlib.pyplot as plt

# First create your base plot with the s2 data
fig, ax = plt.subplots(figsize=(10, 10))
s2_gdf = gpd.GeoDataFrame(s2_band_results, 
                         geometry=gpd.GeoSeries.from_wkt(s2_band_results['boundary_wkt']), 
                         crs=s2_band_results.iloc[0]['crs'])
s2_gdf.plot(column='value', cmap='viridis', legend=True, ax=ax)

# Now load and overlay the GeoJSON boundary
# Replace 'path_to_your_geojson.geojson' with your actual file path
aoi_gdf = gpd.read_file(geojson_path)

# If needed, reproject to match the CRS of your s2_gdf
if aoi_gdf.crs != s2_gdf.crs:
    aoi_gdf = aoi_gdf.to_crs(s2_gdf.crs)

# Plot the AOI boundary on top of the existing plot with a distinct style
aoi_gdf.boundary.plot(ax=ax, color='red', linewidth=2)

# Optional: Add a title and labels
plt.title('S2 Data with AOI Boundary')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.tight_layout()
plt.show()
